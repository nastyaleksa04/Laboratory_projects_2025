# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_7n2o = pd.read_csv('7n2o_h_0001_contacts.csv')

# %%
df_7n2o
# Out:
#          Region Chain  Residue Number Residue Name  Contact Count  \
# 0    CDR1 alpha     D              28            D              0
# 1    CDR1 alpha     D              29            S              0
# 2    CDR1 alpha     D              30            A              1
# 3    CDR1 alpha     D              31            I              1
# 4    CDR1 alpha     D              32            Y              1
# ..          ...   ...             ...          ...            ...
# 171  HLA alpha2     A             179            L              0
# 172  HLA alpha2     A             180            Q              0
# 173  HLA alpha2     A             181            R              0
# 174  HLA alpha2     A             182            A              0
# 175  HLA alpha2     A             183            D              0
#
#      Min Distance (Å) Contacted Peptide AA  Contacted Peptide Number
# 0                 NaN                  NaN                       NaN
# 1                 NaN                  NaN                       NaN
# 2                2.45                    M                       4.0
# 3                3.24                    M                       4.0
# 4                2.44                    L                       6.0
# ..                ...                  ...                       ...
# 171               NaN                  NaN                       NaN
# 172               NaN                  NaN                       NaN
# 173               NaN                  NaN                       NaN
# 174               NaN                  NaN                       NaN
# 175               NaN                  NaN                       NaN
#
# [176 rows x 8 columns]

# %%
df_7n2q = pd.read_csv('7n2q_h_0001_contacts.csv')

# %%
df_7n2q
# Out:
#          Region Chain  Residue Number Residue Name  Contact Count  \
# 0    CDR1 alpha     D              28            D              0
# 1    CDR1 alpha     D              29            S              0
# 2    CDR1 alpha     D              30            A              1
# 3    CDR1 alpha     D              31            I              1
# 4    CDR1 alpha     D              32            Y              1
# ..          ...   ...             ...          ...            ...
# 164  HLA alpha2     A             179            L              0
# 165  HLA alpha2     A             180            Q              0
# 166  HLA alpha2     A             181            R              0
# 167  HLA alpha2     A             182            A              0
# 168  HLA alpha2     A             183            D              0
#
#      Min Distance (Å) Contacted Peptide AA  Contacted Peptide Number
# 0                 NaN                  NaN                       NaN
# 1                 NaN                  NaN                       NaN
# 2                2.33                    M                       4.0
# 3                2.68                    M                       4.0
# 4                2.49                    L                       6.0
# ..                ...                  ...                       ...
# 164               NaN                  NaN                       NaN
# 165               NaN                  NaN                       NaN
# 166               NaN                  NaN                       NaN
# 167               NaN                  NaN                       NaN
# 168               NaN                  NaN                       NaN
#
# [169 rows x 8 columns]

# %%
df_8cx4 = pd.read_csv('8cx4_h_0001_contacts.csv')

# %%
df_8cx4
# Out:
#          Region Chain  Residue Number Residue Name  Contact Count  \
# 0    CDR1 alpha     D              28            D              0
# 1    CDR1 alpha     D              29            S              0
# 2    CDR1 alpha     D              30            A              1
# 3    CDR1 alpha     D              31            I              1
# 4    CDR1 alpha     D              32            Y              1
# ..          ...   ...             ...          ...            ...
# 173  HLA alpha2     A             179            L              0
# 174  HLA alpha2     A             180            Q              0
# 175  HLA alpha2     A             181            R              0
# 176  HLA alpha2     A             182            A              0
# 177  HLA alpha2     A             183            D              0
#
#      Min Distance (Å) Contacted Peptide AA  Contacted Peptide Number
# 0                 NaN                  NaN                       NaN
# 1                 NaN                  NaN                       NaN
# 2                2.45                    M                       4.0
# 3                3.12                    M                       4.0
# 4                2.35                    L                       6.0
# ..                ...                  ...                       ...
# 173               NaN                  NaN                       NaN
# 174               NaN                  NaN                       NaN
# 175               NaN                  NaN                       NaN
# 176               NaN                  NaN                       NaN
# 177               NaN                  NaN                       NaN
#
# [178 rows x 8 columns]

# %%
df_7n2q_2 = pd.read_csv('7n2q_L_B2702_0001_contacts.csv')

# %%
df_7n2q_2
# Out:
#          Region Chain  Residue Number Residue Name  Contact Count  \
# 0    CDR1 alpha     D              27            D              0
# 1    CDR1 alpha     D              29            S              1
# 2    CDR1 alpha     D              30            A              1
# 3    CDR1 alpha     D              31            I              1
# 4    CDR1 alpha     D              32            Y              1
# ..          ...   ...             ...          ...            ...
# 167  HLA alpha2     A             176            K              0
# 168  HLA alpha2     A             177            E              0
# 169  HLA alpha2     A             178            T              0
# 170  HLA alpha2     A             179            L              0
# 171  HLA alpha2     A             180            Q              0
#
#      Min Distance (Å) Contacted Peptide AA  Contacted Peptide Number
# 0                 NaN                  NaN                       NaN
# 1                4.71                    M                       4.0
# 2                2.56                    M                       4.0
# 3                2.89                    M                       4.0
# 4                2.60                    L                       6.0
# ..                ...                  ...                       ...
# 167               NaN                  NaN                       NaN
# 168               NaN                  NaN                       NaN
# 169               NaN                  NaN                       NaN
# 170               NaN                  NaN                       NaN
# 171               NaN                  NaN                       NaN
#
# [172 rows x 8 columns]

# %%
df_7n2o_2 = pd.read_csv('7n2o_L_B2702_0001_contacts.csv')

# %%
df_7n2o_2
# Out:
#          Region Chain  Residue Number Residue Name  Contact Count  \
# 0    CDR1 alpha     D              27            D              0
# 1    CDR1 alpha     D              29            S              1
# 2    CDR1 alpha     D              30            A              1
# 3    CDR1 alpha     D              31            I              1
# 4    CDR1 alpha     D              32            Y              1
# ..          ...   ...             ...          ...            ...
# 173  HLA alpha2     A             176            K              0
# 174  HLA alpha2     A             177            E              0
# 175  HLA alpha2     A             178            T              0
# 176  HLA alpha2     A             179            L              0
# 177  HLA alpha2     A             180            Q              0
#
#      Min Distance (Å) Contacted Peptide AA  Contacted Peptide Number
# 0                 NaN                  NaN                       NaN
# 1                4.32                    M                       4.0
# 2                2.20                    M                       4.0
# 3                2.53                    M                       4.0
# 4                2.19                    L                       6.0
# ..                ...                  ...                       ...
# 173               NaN                  NaN                       NaN
# 174               NaN                  NaN                       NaN
# 175               NaN                  NaN                       NaN
# 176               NaN                  NaN                       NaN
# 177               NaN                  NaN                       NaN
#
# [178 rows x 8 columns]

# %%
df_8cx4_2 = pd.read_csv('8cx4_L_B2702_0001_contacts.csv')

# %%
df_8cx4_2
# Out:
#          Region Chain  Residue Number Residue Name  Contact Count  \
# 0    CDR1 alpha     D              27            D              0
# 1    CDR1 alpha     D              29            S              0
# 2    CDR1 alpha     D              30            A              1
# 3    CDR1 alpha     D              31            I              1
# 4    CDR1 alpha     D              32            Y              1
# ..          ...   ...             ...          ...            ...
# 172  HLA alpha2     A             176            K              0
# 173  HLA alpha2     A             177            E              0
# 174  HLA alpha2     A             178            T              0
# 175  HLA alpha2     A             179            L              0
# 176  HLA alpha2     A             180            Q              0
#
#      Min Distance (Å) Contacted Peptide AA  Contacted Peptide Number
# 0                 NaN                  NaN                       NaN
# 1                 NaN                  NaN                       NaN
# 2                2.47                    M                       4.0
# 3                2.93                    M                       4.0
# 4                2.76                    L                       6.0
# ..                ...                  ...                       ...
# 172               NaN                  NaN                       NaN
# 173               NaN                  NaN                       NaN
# 174               NaN                  NaN                       NaN
# 175               NaN                  NaN                       NaN
# 176               NaN                  NaN                       NaN
#
# [177 rows x 8 columns]

# %% [markdown]
# **Посчитаем по всем CDR:**

# %%
target_regions = ['CDR1 alpha', 'CDR2 alpha', 'CDR3 alpha', 'CDR1 beta', 'CDR2 beta', 'CDR3 beta']

total_contact_7n2q = df_7n2q[df_7n2q['Region'].isin(target_regions)]['Contact Count'].sum()
total_contact_7n2q_2 = df_7n2q_2[df_7n2q_2['Region'].isin(target_regions)]['Contact Count'].sum()
total_contact_7n2o = df_7n2o[df_7n2o['Region'].isin(target_regions)]['Contact Count'].sum()
total_contact_7n2o_2 = df_7n2o_2[df_7n2o_2['Region'].isin(target_regions)]['Contact Count'].sum()
total_contact_8cx4 = df_8cx4[df_8cx4['Region'].isin(target_regions)]['Contact Count'].sum()
total_contact_8cx4_2 = df_8cx4_2[df_8cx4_2['Region'].isin(target_regions)]['Contact Count'].sum()

# %%
summary_cdr = {'7n2o_B2705': total_contact_7n2o, '7n2o_B2702': total_contact_7n2o_2, '7n2q_B2705': total_contact_7n2q, '7n2q_B2702': total_contact_7n2q_2, '8cx4_B2705': total_contact_8cx4, '8cx4_B2702': total_contact_8cx4_2}
summary_cdr
# Out:
# {'7n2o_B2705': 31,
#  '7n2o_B2702': 31,
#  '7n2q_B2705': 28,
#  '7n2q_B2702': 28,
#  '8cx4_B2705': 29,
#  '8cx4_B2702': 25}

# %%
plot_df = pd.DataFrame(list(summary_cdr.items()), columns=['Structure', 'Contacts'])
plot_df
# Out:
#     Structure  Contacts
# 0  7n2o_B2705        31
# 1  7n2o_B2702        31
# 2  7n2q_B2705        28
# 3  7n2q_B2702        28
# 4  8cx4_B2705        29
# 5  8cx4_B2702        25

# %%
plt.figure(figsize=(10, 8))
sns.barplot(
    data=plot_df,
    x='Structure',
    y='Contacts',
    hue='Structure',         
    palette='pastel',
    edgecolor='black',
    legend=False             
)
plt.ylabel('Total Contacts')
plt.title('Сумма контактов по CDR')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Посчитаем отдельно по каждому CDR:**

# %%
target_regions = ['CDR1 alpha', 'CDR2 alpha', 'CDR3 alpha', 'CDR1 beta', 'CDR2 beta', 'CDR3 beta']
structures = ['7n2o', '7n2o_2', '7n2q', '7n2q_2', '8cx4', '8cx4_2']
results = []

for struct in structures:
    df_name = f'df_{struct}'
    df = globals().get(df_name)


    for region in target_regions:
        total_contact = df[df['Region'] == region]['Contact Count'].sum()
        results.append({'Structure': struct, 'Region': region, 'TotalContact': total_contact})

summary_df = pd.DataFrame(results)
summary_df
# Out:
#    Structure      Region  TotalContact
# 0       7n2o  CDR1 alpha             5
# 1       7n2o  CDR2 alpha             3
# 2       7n2o  CDR3 alpha             6
# 3       7n2o   CDR1 beta             0
# 4       7n2o   CDR2 beta             1
# 5       7n2o   CDR3 beta            16
# 6     7n2o_2  CDR1 alpha             6
# 7     7n2o_2  CDR2 alpha             3
# 8     7n2o_2  CDR3 alpha             6
# 9     7n2o_2   CDR1 beta             0
# 10    7n2o_2   CDR2 beta             1
# 11    7n2o_2   CDR3 beta            15
# 12      7n2q  CDR1 alpha             6
# 13      7n2q  CDR2 alpha             2
# 14      7n2q  CDR3 alpha             4
# 15      7n2q   CDR1 beta             0
# 16      7n2q   CDR2 beta             2
# 17      7n2q   CDR3 beta            14
# 18    7n2q_2  CDR1 alpha             7
# 19    7n2q_2  CDR2 alpha             2
# 20    7n2q_2  CDR3 alpha             4
# 21    7n2q_2   CDR1 beta             0
# 22    7n2q_2   CDR2 beta             2
# 23    7n2q_2   CDR3 beta            13
# 24      8cx4  CDR1 alpha             5
# 25      8cx4  CDR2 alpha             4
# 26      8cx4  CDR3 alpha             6
# 27      8cx4   CDR1 beta             0
# 28      8cx4   CDR2 beta             0
# 29      8cx4   CDR3 beta            14
# 30    8cx4_2  CDR1 alpha             5
# 31    8cx4_2  CDR2 alpha             1
# 32    8cx4_2  CDR3 alpha             5
# 33    8cx4_2   CDR1 beta             0
# 34    8cx4_2   CDR2 beta             1
# 35    8cx4_2   CDR3 beta            13

# %%
regions = summary_df['Region'].unique()

fig, axes = plt.subplots(nrows=1, ncols=len(regions), figsize=(5 * len(regions), 5), sharey=True)

if len(regions) == 1:
    axes = [axes]

for ax, region in zip(axes, regions):
    region_df = summary_df[summary_df['Region'] == region]
    sns.barplot(
        data=region_df,
        x='Structure',
        y='TotalContact',
        hue='Structure',          
        palette='pastel',
        edgecolor='black',
        ax=ax,
        legend=False             
    )
    ax.set_title(region)
    ax.set_ylabel('Total Contacts')
    ax.set_xlabel('Structure')
    ax.tick_params(axis='x', rotation=45)

# %% [markdown]
# **Посчитаем по HLA (суммарно по двум альфа-спиралям):**

# %%
target_regions = ['HLA alpha1', 'HLA alpha2']
structures = ['7n2o', '7n2o_2', '7n2q', '7n2q_2', '8cx4', '8cx4_2']
results = []

for struct in structures:
    df_name = f'df_{struct}'
    df = globals().get(df_name)


    for region in target_regions:
        total_contact = df[df['Region'] == region]['Contact Count'].sum()
        results.append({'Structure': struct, 'Region': region, 'TotalContact': total_contact})

summary_df_hla = pd.DataFrame(results)
hla_total_df = (
    summary_df_hla
    .groupby('Structure')['TotalContact']
    .sum()
    .reset_index()
    .rename(columns={'TotalContact': 'HLA_TotalContact'})
)
hla_total_df
# Out:
#   Structure  HLA_TotalContact
# 0      7n2o                52
# 1    7n2o_2                58
# 2      7n2q                50
# 3    7n2q_2                58
# 4      8cx4                52
# 5    8cx4_2                59

# %%
plt.figure(figsize=(10, 8))
sns.barplot(
    data=hla_total_df,
    x='Structure',
    y='HLA_TotalContact',
    hue='Structure',         
    palette='pastel',
    edgecolor='black',
    legend=False             
)
plt.ylabel('Total Contacts')
plt.title('HLA-peptide')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Разницы контактов:**
#
# delta = structure_B2702 - structure_B2705

# %%
structure_pairs = [
    ('7n2o', '7n2o_2'),
    ('7n2q', '7n2q_2'),
    ('8cx4', '8cx4_2'),
]

delta_results = []

for base, alt in structure_pairs:
    base_val = hla_total_df[hla_total_df['Structure'] == base]['HLA_TotalContact'].iloc[0]
    alt_val = hla_total_df[hla_total_df['Structure'] == alt]['HLA_TotalContact'].iloc[0]

    delta = alt_val - base_val  # delta = structure_B2702 - structure_B2705

    delta_results.append({
        'Structure': base,
        'Delta': delta
    })

delta_df_hla = pd.DataFrame(delta_results)

# %%
structure_pairs = [
    ('7n2o', '7n2o_2'),
    ('7n2q', '7n2q_2'),
    ('8cx4', '8cx4_2'),
]

delta_results = []

for base, alt in structure_pairs:
    df_base = summary_df[summary_df['Structure'] == base].set_index('Region')
    df_alt = summary_df[summary_df['Structure'] == alt].set_index('Region')

    common_regions = df_base.index.intersection(df_alt.index)

    for region in common_regions:
        delta = df_alt.loc[region, 'TotalContact'] - df_base.loc[region, 'TotalContact']
        delta_results.append({
            'Structure': base,
            'Region': region,
            'Delta': delta
        })

delta_df = pd.DataFrame(delta_results)

# %%
delta_df_hla['Region'] = 'HLA'

delta_df = pd.concat([delta_df, delta_df_hla], ignore_index=True)
delta_df
# Out:
#    Structure      Region  Delta
# 0       7n2o  CDR1 alpha      1
# 1       7n2o  CDR2 alpha      0
# 2       7n2o  CDR3 alpha      0
# 3       7n2o   CDR1 beta      0
# 4       7n2o   CDR2 beta      0
# 5       7n2o   CDR3 beta     -1
# 6       7n2q  CDR1 alpha      1
# 7       7n2q  CDR2 alpha      0
# 8       7n2q  CDR3 alpha      0
# 9       7n2q   CDR1 beta      0
# 10      7n2q   CDR2 beta      0
# 11      7n2q   CDR3 beta     -1
# 12      8cx4  CDR1 alpha      0
# 13      8cx4  CDR2 alpha     -3
# 14      8cx4  CDR3 alpha     -1
# 15      8cx4   CDR1 beta      0
# 16      8cx4   CDR2 beta      1
# 17      8cx4   CDR3 beta     -1
# 18      7n2o         HLA      6
# 19      7n2q         HLA      8
# 20      8cx4         HLA      7

# %% [markdown]
# **Посчитаем через коэффициенты энергий TCRen:**

# %%
energy_df = pd.read_csv("TCRen_potential.csv")
energy_df
# Out:
#     residue.aa.from residue.aa.to     TCRen
# 0                 A             A -0.159822
# 1                 A             C -0.226424
# 2                 A             D  0.921459
# 3                 A             E  0.044066
# 4                 A             F  0.018394
# ..              ...           ...       ...
# 375               Y             S  0.479961
# 376               Y             T  0.539116
# 377               Y             V -0.204149
# 378               Y             W -0.556273
# 379               Y             Y -0.068726
#
# [380 rows x 3 columns]

# %%
structure_list = ['7n2o', '7n2o_2', '7n2q', '7n2q_2', '8cx4', '8cx4_2']  
result_by_structure = {}

for structure in structure_list:
    df = globals()[f'df_{structure}']
    df.columns = ['Region', 'Chain', 'Residue Number', 'residue.aa.from',
                  'Contact Count', 'Min Distance (Å)', 'residue.aa.to',
                  'Contacted Peptide Number']
    
    merged_df = pd.merge(df, energy_df, on=['residue.aa.from', 'residue.aa.to'], how='inner')
    merged_df['Energy'] = merged_df['TCRen'] * merged_df['Contact Count']

    energy_sum = merged_df.groupby("Region")["Energy"].sum().reset_index()

    result_by_structure[structure] = energy_sum

# %%
all_energy_df = pd.concat(
    [
        df.assign(Structure=structure)
        for structure, df in result_by_structure.items()
    ],
    ignore_index=True
)

all_energy_df = all_energy_df[['Structure', 'Region', 'Energy']]

# %%
all_energy_df
# Out:
#    Structure      Region    Energy
# 0       7n2o  CDR1 alpha -0.272731
# 1       7n2o  CDR2 alpha  0.176002
# 2       7n2o   CDR2 beta -0.008298
# 3       7n2o  CDR3 alpha -0.398131
# 4       7n2o   CDR3 beta -1.024744
# 5       7n2o  HLA alpha1 -1.866243
# 6       7n2o  HLA alpha2  0.517524
# 7     7n2o_2  CDR1 alpha -0.294483
# 8     7n2o_2  CDR2 alpha  0.176002
# 9     7n2o_2   CDR2 beta -0.008298
# 10    7n2o_2  CDR3 alpha -0.366490
# 11    7n2o_2   CDR3 beta -0.670969
# 12    7n2o_2  HLA alpha1  0.824195
# 13    7n2o_2  HLA alpha2 -0.179317
# 14      7n2q  CDR1 alpha -0.323106
# 15      7n2q  CDR2 alpha  0.005152
# 16      7n2q   CDR2 beta -0.100044
# 17      7n2q  CDR3 alpha -0.028888
# 18      7n2q   CDR3 beta -0.409459
# 19      7n2q  HLA alpha1 -1.024928
# 20      7n2q  HLA alpha2  0.131206
# 21    7n2q_2  CDR1 alpha -0.498632
# 22    7n2q_2  CDR2 alpha -0.043503
# 23    7n2q_2   CDR2 beta -0.100044
# 24    7n2q_2  CDR3 alpha -0.158503
# 25    7n2q_2   CDR3 beta -0.203739
# 26    7n2q_2  HLA alpha1  0.518097
# 27    7n2q_2  HLA alpha2  2.511454
# 28      8cx4  CDR1 alpha -0.272731
# 29      8cx4  CDR2 alpha  0.395507
# 30      8cx4  CDR3 alpha -0.808699
# 31      8cx4   CDR3 beta -0.633787
# 32      8cx4  HLA alpha1 -0.518423
# 33      8cx4  HLA alpha2  0.559438
# 34    8cx4_2  CDR1 alpha -0.272731
# 35    8cx4_2  CDR2 alpha -0.021751
# 36    8cx4_2   CDR2 beta -0.008298
# 37    8cx4_2  CDR3 alpha -0.664692
# 38    8cx4_2   CDR3 beta -0.644963
# 39    8cx4_2  HLA alpha1 -0.977574
# 40    8cx4_2  HLA alpha2  0.999301

# %%
grouped = all_energy_df.groupby(['Structure', 'Region'], as_index=False)['Energy'].sum()

hla_grouped = grouped[grouped['Region'].isin(['HLA alpha1', 'HLA alpha2'])]

hla_summed = hla_grouped.groupby('Structure', as_index=False)['Energy'].sum()
hla_summed['Region'] = 'HLA'

non_hla = grouped[~grouped['Region'].isin(['HLA alpha1', 'HLA alpha2'])]

all_energy_df = pd.concat([non_hla, hla_summed], ignore_index=True)

all_energy_df = all_energy_df[['Structure', 'Region', 'Energy']]

# %%
all_energy_df
# Out:
#    Structure      Region    Energy
# 0       7n2o  CDR1 alpha -0.272731
# 1       7n2o  CDR2 alpha  0.176002
# 2       7n2o   CDR2 beta -0.008298
# 3       7n2o  CDR3 alpha -0.398131
# 4       7n2o   CDR3 beta -1.024744
# 5     7n2o_2  CDR1 alpha -0.294483
# 6     7n2o_2  CDR2 alpha  0.176002
# 7     7n2o_2   CDR2 beta -0.008298
# 8     7n2o_2  CDR3 alpha -0.366490
# 9     7n2o_2   CDR3 beta -0.670969
# 10      7n2q  CDR1 alpha -0.323106
# 11      7n2q  CDR2 alpha  0.005152
# 12      7n2q   CDR2 beta -0.100044
# 13      7n2q  CDR3 alpha -0.028888
# 14      7n2q   CDR3 beta -0.409459
# 15    7n2q_2  CDR1 alpha -0.498632
# 16    7n2q_2  CDR2 alpha -0.043503
# 17    7n2q_2   CDR2 beta -0.100044
# 18    7n2q_2  CDR3 alpha -0.158503
# 19    7n2q_2   CDR3 beta -0.203739
# 20      8cx4  CDR1 alpha -0.272731
# 21      8cx4  CDR2 alpha  0.395507
# 22      8cx4  CDR3 alpha -0.808699
# 23      8cx4   CDR3 beta -0.633787
# 24    8cx4_2  CDR1 alpha -0.272731
# 25    8cx4_2  CDR2 alpha -0.021751
# 26    8cx4_2   CDR2 beta -0.008298
# 27    8cx4_2  CDR3 alpha -0.664692
# 28    8cx4_2   CDR3 beta -0.644963
# 29      7n2o         HLA -1.348720
# 30    7n2o_2         HLA  0.644878
# 31      7n2q         HLA -0.893722
# 32    7n2q_2         HLA  3.029552
# 33      8cx4         HLA  0.041014
# 34    8cx4_2         HLA  0.021728

# %%
cdr_regions = ['CDR1 alpha', 'CDR2 alpha', 'CDR3 alpha', 'CDR1 beta', 'CDR2 beta', 'CDR3 beta']
cdr_df = all_energy_df[all_energy_df['Region'].isin(cdr_regions)]

cdr_sums = cdr_df.groupby('Structure', as_index=False)['Energy'].sum()
cdr_sums.rename(columns={'Energy': 'CDR_sum'}, inplace=True)

print(cdr_sums)
# Out:
#   Structure   CDR_sum
# 0      7n2o -1.527903
# 1    7n2o_2 -1.164237
# 2      7n2q -0.856345
# 3    7n2q_2 -1.004421
# 4      8cx4 -1.319711
# 5    8cx4_2 -1.612436

# %% [markdown]
# **Разницы энергий TCRen:**
#
# delta=structure_2 (B2702) - structure (B2705)

# %%
structure_pairs = [
    ('7n2o', '7n2o_2'),
    ('7n2q', '7n2q_2'),
    ('8cx4', '8cx4_2')
]

structure_energy_map = {
    struct: all_energy_df[all_energy_df['Structure'] == struct].set_index('Region')
    for struct in all_energy_df['Structure'].unique()
}

delta_energy_rows = []

for struct1, struct2 in structure_pairs:
    df1 = structure_energy_map.get(struct1)
    df2 = structure_energy_map.get(struct2)
    
    if df1 is None or df2 is None:
        continue

    merged = df1[['Energy']].rename(columns={'Energy': 'Energy_1'}).join(
        df2[['Energy']].rename(columns={'Energy': 'Energy_2'}),
        how='inner'
    )
#delta=structure_2 (B2702) - structure (B2705)

    merged['Delta_Energy'] = merged['Energy_2'] - merged['Energy_1']
    merged['Structure_1'] = struct1
    merged['Structure_2'] = struct2
    merged = merged.reset_index()[['Region', 'Structure_1', 'Structure_2', 'Delta_Energy']]
    
    delta_energy_rows.append(merged)
delta_energy_df = pd.concat(delta_energy_rows, ignore_index=True)

# %%
delta_energy_df
# Out:
#         Region Structure_1 Structure_2  Delta_Energy
# 0   CDR1 alpha        7n2o      7n2o_2     -0.021751
# 1   CDR2 alpha        7n2o      7n2o_2      0.000000
# 2    CDR2 beta        7n2o      7n2o_2      0.000000
# 3   CDR3 alpha        7n2o      7n2o_2      0.031642
# 4    CDR3 beta        7n2o      7n2o_2      0.353775
# 5          HLA        7n2o      7n2o_2      1.993598
# 6   CDR1 alpha        7n2q      7n2q_2     -0.175526
# 7   CDR2 alpha        7n2q      7n2q_2     -0.048654
# 8    CDR2 beta        7n2q      7n2q_2      0.000000
# 9   CDR3 alpha        7n2q      7n2q_2     -0.129615
# 10   CDR3 beta        7n2q      7n2q_2      0.205720
# 11         HLA        7n2q      7n2q_2      3.923274
# 12  CDR1 alpha        8cx4      8cx4_2      0.000000
# 13  CDR2 alpha        8cx4      8cx4_2     -0.417258
# 14  CDR3 alpha        8cx4      8cx4_2      0.144006
# 15   CDR3 beta        8cx4      8cx4_2     -0.011176
# 16         HLA        8cx4      8cx4_2     -0.019287

# %% [markdown]
# **Разница множеств контактов**

# %%
def extract_contact_set(df):
    df_filtered = df[df['residue.aa.to'].notna()]
    return set(zip(
        df_filtered['Region'],
        df_filtered['Chain'],
        df_filtered['Residue Number'],
        df_filtered['residue.aa.from'],
        df_filtered['residue.aa.to'],
        df_filtered['Contacted Peptide Number']
    ))

# %%
structure_pairs = [
    ('7n2o', '7n2o_2'),
    ('7n2q', '7n2q_2'),
    ('8cx4', '8cx4_2')
]


all_results = []

for struct1, struct2 in structure_pairs:
    df1 = globals()[f'df_{struct1}']
    df2 = globals()[f'df_{struct2}']

    set1 = extract_contact_set(df1)
    set2 = extract_contact_set(df2)

    union_contacts = set1 | set2

    for contact in union_contacts:
        all_results.append({
            'Region': contact[0],
            'Chain': contact[1],
            'Residue Number': contact[2],
            'residue.aa.from': contact[3],
            'residue.aa.to': contact[4],
            'Contacted Peptide Number': contact[5],
            'In_structure_1': contact in set1,
            'In_structure_2': contact in set2,
            'Structure_1_name': struct1,
            'Structure_2_name': struct2
        })

result_df = pd.DataFrame(all_results)

# %%
result_df
# Out:
#          Region Chain  Residue Number residue.aa.from residue.aa.to  \
# 0    HLA alpha1     A              66               I             M
# 1    CDR2 alpha     D              66               S             M
# 2     CDR3 beta     F              99               S             M
# 3    HLA alpha1     A              70               K             M
# 4    CDR3 alpha     D             133               S             L
# ..          ...   ...             ...             ...           ...
# 350  HLA alpha2     A             155               Q             M
# 351   CDR3 beta     F              97               T             L
# 352  CDR3 alpha     D              96               P             M
# 353  CDR3 alpha     D             102               S             L
# 354  HLA alpha1     A              63               E             L
#
#      Contacted Peptide Number  In_structure_1  In_structure_2  \
# 0                         5.0            True            True
# 1                         4.0           False            True
# 2                         5.0            True           False
# 3                         5.0            True            True
# 4                         6.0           False            True
# ..                        ...             ...             ...
# 350                       5.0            True            True
# 351                       6.0            True           False
# 352                       4.0            True           False
# 353                       6.0            True           False
# 354                       1.0            True            True
#
#     Structure_1_name Structure_2_name
# 0               7n2o           7n2o_2
# 1               7n2o           7n2o_2
# 2               7n2o           7n2o_2
# 3               7n2o           7n2o_2
# 4               7n2o           7n2o_2
# ..               ...              ...
# 350             8cx4           8cx4_2
# 351             8cx4           8cx4_2
# 352             8cx4           8cx4_2
# 353             8cx4           8cx4_2
# 354             8cx4           8cx4_2
#
# [355 rows x 10 columns]

# %%
result_df.to_csv('diff_set_contacts.csv')

# %%
df_hla_tcr_7n2o = pd.read_csv('7n2o_h_0001_cdr_hla_contacts.csv')
df_hla_tcr_7n2o_2 = pd.read_csv('7n2o_L_B2702_0001_cdr_hla_contacts.csv')
df_hla_tcr_7n2q = pd.read_csv('7n2q_h_0001_cdr_hla_contacts.csv')
df_hla_tcr_7n2q_2 = pd.read_csv('7n2q_L_B2702_0001_cdr_hla_contacts.csv')
df_hla_tcr_8cx4 = pd.read_csv('8cx4_h_0001_cdr_hla_contacts.csv')
df_hla_tcr_8cx4_2 = pd.read_csv('8cx4_L_B2702_0001_cdr_hla_contacts.csv')

total_contact_7n2q = df_hla_tcr_7n2q.shape[0]
total_contact_7n2q_2 = df_hla_tcr_7n2q_2.shape[0]
total_contact_7n2o = df_hla_tcr_7n2o.shape[0]
total_contact_7n2o_2 = df_hla_tcr_7n2o_2.shape[0]
total_contact_8cx4 = df_hla_tcr_8cx4.shape[0]
total_contact_8cx4_2 = df_hla_tcr_8cx4_2.shape[0]

summary_cdr_hla = {'7n2o_B2705': total_contact_7n2o, '7n2o_B2702': total_contact_7n2o_2, '7n2q_B2705': total_contact_7n2q, '7n2q_B2702': total_contact_7n2q_2, '8cx4_B2705': total_contact_8cx4, '8cx4_B2702': total_contact_8cx4_2}
plot_df = pd.DataFrame(list(summary_cdr_hla.items()), columns=['Structure', 'Contacts'])

plt.figure(figsize=(10, 8))
sns.barplot(
    data=plot_df,
    x='Structure',
    y='Contacts',
    hue='Structure',         
    palette='pastel',
    edgecolor='black',
    legend=False             
)
plt.ylabel('Total Contacts')
plt.title('CDR-HLA')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

structure_list = ['7n2o', '7n2o_2', '7n2q', '7n2q_2', '8cx4', '8cx4_2']  
result_by_structure = {}

for structure in structure_list:
    df = globals()[f'df_hla_tcr_{structure}']
    df.columns = ['CDR Region', 'CDR Chain', 'CDR Residue Number', 'residue.aa.from',
                  'HLA Region', 'HLA Chain', 'HLA Residue Number', 'residue.aa.to',
                  'Distance (Å)']
    
    merged_df = pd.merge(df, energy_df, on=['residue.aa.from', 'residue.aa.to'], how='inner')
    merged_df['Energy'] = merged_df['TCRen'] * 1

    energy_sum = merged_df.groupby("CDR Region")["Energy"].sum().reset_index()

    result_by_structure[structure] = energy_sum
    

all_energy_df = pd.concat(
    [
        df.assign(Structure=structure)
        for structure, df in result_by_structure.items()
    ],
    ignore_index=True
)

all_energy_df = all_energy_df[['Structure', 'CDR Region', 'Energy']]

cdr_regions = ['CDR1 alpha', 'CDR2 alpha', 'CDR3 alpha', 'CDR1 beta', 'CDR2 beta', 'CDR3 beta']
cdr_df = all_energy_df[all_energy_df['CDR Region'].isin(cdr_regions)]

cdr_sums = cdr_df.groupby('Structure', as_index=False)['Energy'].sum()
cdr_sums.rename(columns={'Energy': 'CDR_sum'}, inplace=True)

print(cdr_sums)
# Out:
#   Structure     CDR_sum
# 0      7n2o   77.680018
# 1    7n2o_2  169.462436
# 2      7n2q  250.030261
# 3    7n2q_2  189.844344
# 4      8cx4  181.154057
# 5    8cx4_2  114.753622

# %%
plot_df
# Out:
#     Structure  Contacts
# 0  7n2o_B2705      1828
# 1  7n2o_B2702      1368
# 2  7n2q_B2705      1512
# 3  7n2q_B2702      1264
# 4  8cx4_B2705      1279
# 5  8cx4_B2702      1083

# %%
df_tcren_new = pd.read_csv('TCRen_potentials.csv')

structure_list = ['7n2o', '7n2o_2', '7n2q', '7n2q_2', '8cx4', '8cx4_2']  
result_by_structure_new = {}

for structure in structure_list:
    df = globals()[f'df_{structure}']
    df.columns = ['Region', 'Chain', 'Residue Number', 'residue.aa.from',
                  'Contact Count', 'Min Distance (Å)', 'residue.aa.to',
                  'Contacted Peptide Number']
    
    merged_df_new = pd.merge(df, df_tcren_new, on=['residue.aa.from', 'residue.aa.to'], how='inner')
    merged_df_new['Energy'] = merged_df_new['TCRen'] * merged_df_new['Contact Count']

    energy_sum_new = merged_df_new.groupby("Region")["Energy"].sum().reset_index()

    result_by_structure_new[structure] = energy_sum_new

all_energy_df_new = pd.concat(
    [
        df.assign(Structure=structure)
        for structure, df in result_by_structure_new.items()
    ],
    ignore_index=True
)

all_energy_df_new = all_energy_df_new[['Structure', 'Region', 'Energy']]


grouped = all_energy_df_new.groupby(['Structure', 'Region'], as_index=False)['Energy'].sum()

hla_grouped_new = grouped[grouped['Region'].isin(['HLA alpha1', 'HLA alpha2'])]

hla_summed_new = hla_grouped_new.groupby('Structure', as_index=False)['Energy'].sum()
hla_summed_new['Region'] = 'HLA'

non_hla_new = grouped[~grouped['Region'].isin(['HLA alpha1', 'HLA alpha2'])]

all_energy_df_new = pd.concat([non_hla_new, hla_summed_new], ignore_index=True)

all_energy_df_new = all_energy_df_new[['Structure', 'Region', 'Energy']]
print(all_energy_df_new)

cdr_regions = ['CDR1 alpha', 'CDR2 alpha', 'CDR3 alpha', 'CDR1 beta', 'CDR2 beta', 'CDR3 beta']
cdr_df_new = all_energy_df_new[all_energy_df_new['Region'].isin(cdr_regions)]

cdr_sums_new = cdr_df_new.groupby('Structure', as_index=False)['Energy'].sum()
cdr_sums_new.rename(columns={'Energy': 'CDR_sum'}, inplace=True)

print("Сумма энергий по CDR:")
print(cdr_sums_new)

structure_list = ['7n2o', '7n2o_2', '7n2q', '7n2q_2', '8cx4', '8cx4_2']  
result_by_structure = {}

for structure in structure_list:
    df = globals()[f'df_hla_tcr_{structure}']
    df.columns = ['CDR Region', 'CDR Chain', 'CDR Residue Number', 'residue.aa.from',
                  'HLA Region', 'HLA Chain', 'HLA Residue Number', 'residue.aa.to',
                  'Distance (Å)']
    
    merged_df = pd.merge(df, energy_df, on=['residue.aa.from', 'residue.aa.to'], how='inner')
    merged_df['Energy'] = merged_df['TCRen'] * 1

    energy_sum = merged_df.groupby("CDR Region")["Energy"].sum().reset_index()

    result_by_structure[structure] = energy_sum
    
    
    
all_energy_df = pd.concat(
    [
        df.assign(Structure=structure)
        for structure, df in result_by_structure.items()
    ],
    ignore_index=True
)

all_energy_df = all_energy_df[['Structure', 'CDR Region', 'Energy']]


cdr_regions = ['CDR1 alpha', 'CDR2 alpha', 'CDR3 alpha', 'CDR1 beta', 'CDR2 beta', 'CDR3 beta']
cdr_df = all_energy_df[all_energy_df['CDR Region'].isin(cdr_regions)]

cdr_sums = cdr_df.groupby('Structure', as_index=False)['Energy'].sum()
cdr_sums.rename(columns={'Energy': 'CDR_sum'}, inplace=True)

print("Энергии HLA-CDR:")
print(cdr_sums)
# Out:
#    Structure      Region    Energy
# 0       7n2o  CDR1 alpha -0.352408
# 1       7n2o  CDR2 alpha -0.194282
# 2       7n2o   CDR2 beta -0.045475
# 3       7n2o  CDR3 alpha -0.147024
# 4       7n2o   CDR3 beta -0.058742
# 5     7n2o_2  CDR1 alpha -0.442210
# 6     7n2o_2  CDR2 alpha -0.194282
# 7     7n2o_2   CDR2 beta -0.045475
# 8     7n2o_2  CDR3 alpha -0.121519
# 9     7n2o_2   CDR3 beta -0.042833
# 10      7n2q  CDR1 alpha -0.297669
# 11      7n2q  CDR2 alpha -0.118570
# 12      7n2q   CDR2 beta -0.096251
# 13      7n2q  CDR3 alpha -0.051860
# 14      7n2q   CDR3 beta -0.201186
# 15    7n2q_2  CDR1 alpha -0.449145
# 16    7n2q_2  CDR2 alpha -0.179606
# 17    7n2q_2   CDR2 beta -0.096251
# 18    7n2q_2  CDR3 alpha -0.041406
# 19    7n2q_2   CDR3 beta -0.300847
# 20      8cx4  CDR1 alpha -0.352408
# 21      8cx4  CDR2 alpha -0.208959
# 22      8cx4  CDR3 alpha -0.189772
# 23      8cx4   CDR3 beta -0.238994
# 24    8cx4_2  CDR1 alpha -0.352408
# 25    8cx4_2  CDR2 alpha -0.089803
# 26    8cx4_2   CDR2 beta -0.045475
# 27    8cx4_2  CDR3 alpha -0.162188
# 28    8cx4_2   CDR3 beta -0.242130
# 29      7n2o         HLA -1.393835
# 30    7n2o_2         HLA -1.118854
# 31      7n2q         HLA -0.435609
# 32    7n2q_2         HLA -0.455017
# 33      8cx4         HLA -0.464230
# 34    8cx4_2         HLA -1.024848
# Сумма энергий по CDR:
#   Structure   CDR_sum
# 0      7n2o -0.797931
# 1    7n2o_2 -0.846320
# 2      7n2q -0.765537
# 3    7n2q_2 -1.067255
# 4      8cx4 -0.990132
# 5    8cx4_2 -0.892004
# Энергии HLA-CDR:
#   Structure     CDR_sum
# 0      7n2o   77.680018
# 1    7n2o_2  169.462436
# 2      7n2q  250.030261
# 3    7n2q_2  189.844344
# 4      8cx4  181.154057
# 5    8cx4_2  114.753622

# %%
df_final = all_energy_df_new[all_energy_df_new['Region'] == 'HLA']
cdr_sums_new['Energy'] = cdr_sums_new['CDR_sum']
cdr_sums_new['Region'] = 'CDR'
cdr_sums_new = cdr_sums_new.drop(['CDR_sum'], axis=1)
cdr_sums['Energy'] = cdr_sums['CDR_sum']
cdr_sums['Region'] = 'TCR-HLA'
cdr_sums = cdr_sums.drop(['CDR_sum'], axis=1)
df_final = pd.concat([df_final, cdr_sums_new], ignore_index=True)
df_final = pd.concat([df_final, cdr_sums], ignore_index=True)

def normalize_structure(name):
    return name.replace('_2', '')

df_final['Pair'] = df_final['Structure'].apply(normalize_structure)

idx_min = df_final.groupby(['Pair', 'Region'])['Energy'].idxmin()
df_min = df_final.loc[idx_min].copy()

def assign_b270(name):
    return 'B2702' if name.endswith('_2') else 'B2705'

df_min['HLA_type'] = df_min['Structure'].apply(assign_b270)

result = df_min[['Pair', 'Region', 'Energy', 'HLA_type']].reset_index(drop=True)
print(result)
# Out:
#    Pair   Region      Energy HLA_type
# 0  7n2o      CDR   -0.846320    B2702
# 1  7n2o      HLA   -1.393835    B2705
# 2  7n2o  TCR-HLA   77.680018    B2705
# 3  7n2q      CDR   -1.067255    B2702
# 4  7n2q      HLA   -0.455017    B2702
# 5  7n2q  TCR-HLA  189.844344    B2702
# 6  8cx4      CDR   -0.990132    B2705
# 7  8cx4      HLA   -1.024848    B2702
# 8  8cx4  TCR-HLA  114.753622    B2702

# %%
result.to_csv('tcrmodel_5A_allcdrs.csv')

# %% [markdown]
# Разница энергий HLA-peptide - TCR-peptide:

# %%
merged_df = pd.merge(cdr_sums_new, cdr_sums, on='Structure', suffixes=('_df1', '_df2'))

merged_df['Difference'] = merged_df['Energy_df2'] - merged_df['Energy_df1']

result_df = merged_df[['Structure', 'Difference']]

print(result_df)
# Out:
#   Structure  Difference
# 0      7n2o   78.477949
# 1    7n2o_2  170.308756
# 2      7n2q  250.795798
# 3    7n2q_2  190.911600
# 4      8cx4  182.144190
# 5    8cx4_2  115.645626

# %%
mj_k = pd.read_csv('MJ_Keskin_potentials.csv')

df_keskin = mj_k[mj_k['potential'] == 'Keskin'].reset_index(drop=True)
df_mj = mj_k[mj_k['potential'] == 'MJ'].reset_index(drop=True)

structure_list = ['7n2o', '7n2o_2', '7n2q', '7n2q_2', '8cx4', '8cx4_2']  
result_by_structure_new = {}

for structure in structure_list:
    df = globals()[f'df_{structure}']
    df.columns = ['Region', 'Chain', 'Residue Number', 'residue.aa.from',
                  'Contact Count', 'Min Distance (Å)', 'residue.aa.to',
                  'Contacted Peptide Number']
    
    merged_df_new = pd.merge(df, df_mj, on=['residue.aa.from', 'residue.aa.to'], how='inner')
    merged_df_new['MJ_potential'] = merged_df_new['value'] * merged_df_new['Contact Count']

    energy_sum_new = merged_df_new.groupby("Region")["MJ_potential"].sum().reset_index()

    result_by_structure_new[structure] = energy_sum_new

all_energy_df_new = pd.concat(
    [
        df.assign(Structure=structure)
        for structure, df in result_by_structure_new.items()
    ],
    ignore_index=True
)

all_energy_df_new = all_energy_df_new[['Structure', 'Region', 'MJ_potential']]


grouped = all_energy_df_new.groupby(['Structure', 'Region'], as_index=False)['MJ_potential'].sum()

hla_grouped_new = grouped[grouped['Region'].isin(['HLA alpha1', 'HLA alpha2'])]

hla_summed_new = hla_grouped_new.groupby('Structure', as_index=False)['MJ_potential'].sum()
hla_summed_new['Region'] = 'HLA'

non_hla_new = grouped[~grouped['Region'].isin(['HLA alpha1', 'HLA alpha2'])]

all_energy_df_new = pd.concat([non_hla_new, hla_summed_new], ignore_index=True)

all_energy_df_new = all_energy_df_new[['Structure', 'Region', 'MJ_potential']]
print(all_energy_df_new)

cdr_regions = ['CDR1 alpha', 'CDR2 alpha', 'CDR3 alpha', 'CDR1 beta', 'CDR2 beta', 'CDR3 beta']
cdr_df_new = all_energy_df_new[all_energy_df_new['Region'].isin(cdr_regions)]

cdr_sums_new = cdr_df_new.groupby('Structure', as_index=False)['MJ_potential'].sum()
cdr_sums_new.rename(columns={'MJ_potential': 'CDR_sum'}, inplace=True)

print("Суммарный потенциал MJ по CDR:")
print(cdr_sums_new)

structure_list = ['7n2o', '7n2o_2', '7n2q', '7n2q_2', '8cx4', '8cx4_2']  
result_by_structure = {}

for structure in structure_list:
    df = globals()[f'df_hla_tcr_{structure}']
    df.columns = ['CDR Region', 'CDR Chain', 'CDR Residue Number', 'residue.aa.from',
                  'HLA Region', 'HLA Chain', 'HLA Residue Number', 'residue.aa.to',
                  'Distance (Å)']
    
    merged_df = pd.merge(df, df_mj, on=['residue.aa.from', 'residue.aa.to'], how='inner')
    merged_df['MJ_potential'] = merged_df['value'] * 1

    energy_sum = merged_df.groupby("CDR Region")["MJ_potential"].sum().reset_index()

    result_by_structure[structure] = energy_sum
    
    
    
all_energy_df = pd.concat(
    [
        df.assign(Structure=structure)
        for structure, df in result_by_structure.items()
    ],
    ignore_index=True
)

all_energy_df = all_energy_df[['Structure', 'CDR Region', 'MJ_potential']]


cdr_regions = ['CDR1 alpha', 'CDR2 alpha', 'CDR3 alpha', 'CDR1 beta', 'CDR2 beta', 'CDR3 beta']
cdr_df = all_energy_df[all_energy_df['CDR Region'].isin(cdr_regions)]

cdr_sums = cdr_df.groupby('Structure', as_index=False)['MJ_potential'].sum()
cdr_sums.rename(columns={'MJ_potential': 'CDR_sum'}, inplace=True)

print("MJ по HLA-CDR:")
print(cdr_sums)

df_final = all_energy_df_new[all_energy_df_new['Region'] == 'HLA']
cdr_sums_new['MJ_potential'] = cdr_sums_new['CDR_sum']
cdr_sums_new['Region'] = 'CDR'
cdr_sums_new = cdr_sums_new.drop(['CDR_sum'], axis=1)
cdr_sums['MJ_potential'] = cdr_sums['CDR_sum']
cdr_sums['Region'] = 'TCR-HLA'
cdr_sums = cdr_sums.drop(['CDR_sum'], axis=1)
df_final = pd.concat([df_final, cdr_sums_new], ignore_index=True)
df_final = pd.concat([df_final, cdr_sums], ignore_index=True)

def normalize_structure(name):
    return name.replace('_2', '')

df_final['Pair'] = df_final['Structure'].apply(normalize_structure)

idx_min = df_final.groupby(['Pair', 'Region'])['MJ_potential'].idxmin()
df_min = df_final.loc[idx_min].copy()

def assign_b270(name):
    return 'B2702' if name.endswith('_2') else 'B2705'

df_min['HLA_type'] = df_min['Structure'].apply(assign_b270)

result = df_min[['Pair', 'Region', 'MJ_potential', 'HLA_type']].reset_index(drop=True)
print('Минимальная энергия:')
print(result)
# Out:
#    Structure      Region  MJ_potential
# 0       7n2o  CDR1 alpha         -2.60
# 1       7n2o  CDR2 alpha          0.14
# 2       7n2o   CDR2 beta         -0.25
# 3       7n2o  CDR3 alpha         -1.11
# 4       7n2o   CDR3 beta         -3.39
# 5     7n2o_2  CDR1 alpha         -2.55
# 6     7n2o_2  CDR2 alpha          0.14
# 7     7n2o_2   CDR2 beta         -0.25
# 8     7n2o_2  CDR3 alpha         -1.29
# 9     7n2o_2   CDR3 beta         -3.88
# 10      7n2q  CDR1 alpha         -2.56
# 11      7n2q  CDR2 alpha          0.03
# 12      7n2q   CDR2 beta         -0.83
# 13      7n2q  CDR3 alpha         -1.54
# 14      7n2q   CDR3 beta         -1.33
# 15    7n2q_2  CDR1 alpha         -2.93
# 16    7n2q_2  CDR2 alpha          0.10
# 17    7n2q_2   CDR2 beta         -0.83
# 18    7n2q_2  CDR3 alpha         -0.73
# 19    7n2q_2   CDR3 beta         -1.22
# 20      8cx4  CDR1 alpha         -2.60
# 21      8cx4  CDR2 alpha          0.18
# 22      8cx4  CDR3 alpha         -0.93
# 23      8cx4   CDR3 beta         -1.44
# 24    8cx4_2  CDR1 alpha         -2.60
# 25    8cx4_2  CDR2 alpha          0.05
# 26    8cx4_2   CDR2 beta         -0.25
# 27    8cx4_2  CDR3 alpha         -1.04
# 28    8cx4_2   CDR3 beta         -1.31
# 29      7n2o         HLA        -13.27
# 30    7n2o_2         HLA        -13.71
# 31      7n2q         HLA        -11.00
# 32    7n2q_2         HLA        -12.45
# 33      8cx4         HLA         -9.85
# 34    8cx4_2         HLA        -13.23
# Суммарный потенциал MJ по CDR:
#   Structure  CDR_sum
# 0      7n2o    -7.21
# 1    7n2o_2    -7.83
# 2      7n2q    -6.23
# 3    7n2q_2    -5.61
# 4      8cx4    -4.79
# 5    8cx4_2    -5.15
# MJ по HLA-CDR:
#   Structure  CDR_sum
# 0      7n2o   140.42
# 1    7n2o_2    46.57
# 2      7n2q    25.40
# 3    7n2q_2    -9.73
# 4      8cx4    77.18
# 5    8cx4_2    61.07
# Минимальная энергия:
#    Pair   Region  MJ_potential HLA_type
# 0  7n2o      CDR         -7.83    B2702
# 1  7n2o      HLA        -13.71    B2702
# 2  7n2o  TCR-HLA         46.57    B2702
# 3  7n2q      CDR         -6.23    B2705
# 4  7n2q      HLA        -12.45    B2702
# 5  7n2q  TCR-HLA         -9.73    B2702
# 6  8cx4      CDR         -5.15    B2702
# 7  8cx4      HLA        -13.23    B2702
# 8  8cx4  TCR-HLA         61.07    B2702
